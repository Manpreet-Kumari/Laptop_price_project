# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\laptop_price.csv", encoding='cp1252')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
# Conversion rate: 1 Euro = 90 INR (change if needed)
conversion_rate = 90

# Convert to INR and name the column 'Price'
df['Price'] = (df['Price_euros'] * conversion_rate).round(2)

# Drop the old 'Price_euros' column
df.drop(columns='Price_euros', inplace=True)

# Check result
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight     Price
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  120572.1
# ...

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8
# 1                            1440x900        Intel Core i5 1.8GHz   8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight     Price
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS   1.37  120572.1
# ...

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(8)
# memory usage: 112.1+ KB

# %%
import seaborn as sns

# %%
sns.displot(df['Price'])

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Inches'])

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample()
# Out:
#     Company                 Product  TypeName  Inches  \
# 532    Asus  Zenbook UX510UW-FI095T  Notebook    15.6
#
#                     ScreenResolution                         Cpu  Ram  \
# 532  IPS Panel 4K Ultra HD 3840x2160  Intel Core i7 7500U 2.7GHz    8
#
#                    Memory                      Gpu       OpSys  Weight  \
# 532  256GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10     2.0
#
#         Price  Touchscreen
# 532  116910.0            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120572.1            0    1
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x', n=1,expand = True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120572.1            0    1
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120572.1            0    1
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  Ips               1303 non-null   int64
#  14  X_res             1303 non-null   int64
#  15  Y_res             1303 non-null   int64
# ...

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.drop(columns=['ScreenResolution'],inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight     Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37  120572.1
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   80904.6
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   51750.0
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  228370.5
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37  162324.0
#
#    Touchscreen  Ips  X_res  Y_res         ppi
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight     Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37  120572.1
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   80904.6
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   51750.0
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  228370.5
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37  162324.0
#
#    Touchscreen  Ips         ppi
# 0            0    1  226.983005
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu_Name']= df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight     Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37  120572.1
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   80904.6
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   51750.0
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  228370.5
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37  162324.0
#
#    Touchscreen  Ips         ppi       Cpu_Name
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text== 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu_Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight     Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37  120572.1
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   80904.6
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   51750.0
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  228370.5
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37  162324.0
#
#    Touchscreen  Ips         ppi       Cpu_Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight     Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37  120572.1
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   80904.6
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   51750.0
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  228370.5
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37  162324.0
#
#    Touchscreen  Ips         ppi       Cpu_Name      Cpu brand
# ...

# %%
df.drop(columns = ['Cpu','Cpu_Name'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram               Memory  \
# 0   Apple  MacBook Pro  Ultrabook    8            128GB SSD
# 1   Apple  Macbook Air  Ultrabook    8  128GB Flash Storage
# 2      HP       250 G6   Notebook    8            256GB SSD
# 3   Apple  MacBook Pro  Ultrabook   16            512GB SSD
# 4   Apple  MacBook Pro  Ultrabook    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120572.1            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   80904.6            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51750.0            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228370.5            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162324.0            0    1
#
#           ppi      Cpu brand
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

# %%
df["first"] = new[0]
df["first"]=df["first"].str.strip()

# %%
df["second"]=new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x:1 if "Flash Storage" in x else 0)

# %%
df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3380\2969916844.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace = True)

# %%
df["Layer2HDD"] = df["second"].apply(lambda x:1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x:1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage " in x else 0)

# %%
# Step 1: Remove all non-digit characters using regex
df['first'] = df['first'].str.extract('(\d+)')  # Extract digits only
df['second'] = df['second'].str.extract('(\d+)')

# Step 2: Convert to integers safely
df['first'] = df['first'].astype(int)
df['second'] = df['second'].astype(int)

# %%
df["HDD"] = (df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"] = (df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"] = (df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage','Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'], inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram             Memory  \
# 0   Apple  MacBook Pro  Ultrabook    8            128 SSD
# 1   Apple  Macbook Air  Ultrabook    8  128 Flash Storage
# 2      HP       250 G6   Notebook    8            256 SSD
# 3   Apple  MacBook Pro  Ultrabook   16            512 SSD
# 4   Apple  MacBook Pro  Ultrabook    8            256 SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  120572.1            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   80904.6            0    0
# 2         Intel HD Graphics 620  No OS    1.86   51750.0            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  228370.5            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  162324.0            0    1
#
#           ppi      Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5    0  128       0              0
# ...

# %%
df.drop(columns=['Memory'],inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight     Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0    1.37  120572.1            0    1  226.983005  Intel Core i5    0  128
# 1    1.34   80904.6            0    0  127.677940  Intel Core i5    0    0
# 2    1.86   51750.0            0    0  141.211998  Intel Core i5    0  256
# 3    1.83  228370.5            0    1  220.534624  Intel Core i7    0  512
# 4    1.37  162324.0            0    1  226.983005  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# ...

# %%
print(df['Price'].dtype)
# Out:
# float64

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight     Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0    1.37  120572.1            0    1  226.983005  Intel Core i5    0  128
# 1    1.34   80904.6            0    0  127.677940  Intel Core i5    0    0
# 2    1.86   51750.0            0    0  141.211998  Intel Core i5    0  256
# 3    1.83  228370.5            0    1  220.534624  Intel Core i7    0  512
# 4    1.37  162324.0            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight     Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0    1.37  120572.1            0    1  226.983005  Intel Core i5    0  128
# 1    1.34   80904.6            0    0  127.677940  Intel Core i5    0    0
# 2    1.86   51750.0            0    0  141.211998  Intel Core i5    0  256
# 3    1.83  228370.5            0    1  220.534624  Intel Core i7    0  512
# 4    1.37  162324.0            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y = df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram  OpSys  Weight     Price  Touchscreen  \
# 0   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  120572.1            0
# 1   Apple  Macbook Air  Ultrabook    8  macOS    1.34   80904.6            0
# 2      HP       250 G6   Notebook    8  No OS    1.86   51750.0            0
# 3   Apple  MacBook Pro  Ultrabook   16  macOS    1.83  228370.5            0
# 4   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  162324.0            0
#
#    Ips         ppi      Cpu brand  HDD  SSD Gpu brand
# 0    1  226.983005  Intel Core i5    0  128     Intel
# 1    0  127.677940  Intel Core i5    0    0     Intel
# 2    0  141.211998  Intel Core i5    0  256     Intel
# 3    1  220.534624  Intel Core i7    0  512       AMD
# 4    1  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os']= df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram  OpSys  Weight     Price  Touchscreen  \
# 0   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  120572.1            0
# 1   Apple  Macbook Air  Ultrabook    8  macOS    1.34   80904.6            0
# 2      HP       250 G6   Notebook    8  No OS    1.86   51750.0            0
# 3   Apple  MacBook Pro  Ultrabook   16  macOS    1.83  228370.5            0
# 4   Apple  MacBook Pro  Ultrabook    8  macOS    1.37  162324.0            0
#
#    Ips         ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0    1  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1    0  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2    0  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3    1  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4    1  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Weight'])

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3380\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company                              Product            TypeName  Ram  \
# 0      Apple                          MacBook Pro           Ultrabook    8
# 1      Apple                          Macbook Air           Ultrabook    8
# 2         HP                               250 G6            Notebook    8
# 3      Apple                          MacBook Pro           Ultrabook   16
# 4      Apple                          MacBook Pro           Ultrabook    8
# ...      ...                                  ...                 ...  ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    4
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible   16
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    2
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    4
#
# ...

# %%
y
# Out:
# 0       11.700003
# 1       11.301026
# 2       10.854180
# 3       12.338725
# 4       11.997350
#           ...
# 1298    10.958148
# 1299    11.812363
# 1300     9.933532
# 1301    11.138377
# 1302    10.410606
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company              Product            TypeName  Ram  Weight  \
# 183   Toshiba        Satellite Pro            Notebook    8    2.00
# 1141      MSI           GP62M 7RDX              Gaming    8    2.40
# 1049     Asus    Chromebook C202SA             Netbook    4    1.20
# 1020     Dell        Inspiron 5568  2 in 1 Convertible    4    2.08
# 878      Dell          Vostro 5568            Notebook    4    2.18
# ...       ...                  ...                 ...  ...     ...
# 466      Acer             Aspire 5            Notebook    4    2.20
# 299      Asus  ZenBook UX530UQ-PRO           Ultrabook   16    1.63
# 493      Acer             Aspire 5            Notebook    8    2.20
# 527    Lenovo    IdeaPad 320-15ISK            Notebook    8    2.20
# 1193    Apple          MacBook 12"           Ultrabook    8    0.92
#
#       Touchscreen  Ips         ppi              Cpu brand   HDD  SSD  \
# 183             0    0  100.454670          Intel Core i5     0  128
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Company', 'Product', 'TypeName', 'Ram', 'Weight', 'Price', 'Touchscreen', 'Ips', 'ppi', 'Cpu brand', 'HDD', 'SSD', 'Gpu brand', 'os']

# %%
X_train
# Out:
#       Company              Product            TypeName  Ram  Weight  \
# 183   Toshiba        Satellite Pro            Notebook    8    2.00
# 1141      MSI           GP62M 7RDX              Gaming    8    2.40
# 1049     Asus    Chromebook C202SA             Netbook    4    1.20
# 1020     Dell        Inspiron 5568  2 in 1 Convertible    4    2.08
# 878      Dell          Vostro 5568            Notebook    4    2.18
# ...       ...                  ...                 ...  ...     ...
# 466      Acer             Aspire 5            Notebook    4    2.20
# 299      Asus  ZenBook UX530UQ-PRO           Ultrabook   16    1.63
# 493      Acer             Aspire 5            Notebook    8    2.20
# 527    Lenovo    IdeaPad 320-15ISK            Notebook    8    2.20
# 1193    Apple          MacBook 12"           Ultrabook    8    0.92
#
#       Touchscreen  Ips         ppi              Cpu brand   HDD  SSD  \
# 183             0    0  100.454670          Intel Core i5     0  128
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
# !pip install xgboost

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
from xgboost import XGBRegressor

# %%
print(X_train.dtypes)
print(X_train.iloc[0])  # See sample row
# Out:
# Company         object
# Product         object
# TypeName        object
# Ram              int32
# Weight         float32
# Touchscreen      int64
# Ips              int64
# ppi            float64
# Cpu brand       object
# HDD              int64
# SSD              int64
# Gpu brand       object
# os              object
# dtype: object
# Company              Toshiba
# Product        Satellite Pro
# TypeName            Notebook
# Ram                        8
# Weight                   2.0
# Touchscreen                0
# Ips                        0
# ppi                100.45467
# Cpu brand      Intel Core i5
# HDD                        0
# SSD                      128
# Gpu brand              Intel
# os                   Windows
# Name: 183, dtype: object

# %%
np.exp(0.21)
# Out:
# np.float64(1.2336780599567432)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score, mean_absolute_error

# Categorical columns to encode
categorical_cols = ['Company', 'Product', 'TypeName', 'Cpu brand', 'Gpu brand', 'os']

# Step 1: Preprocessing
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), categorical_cols)
], remainder='passthrough')

# Step 2: Lasso Regression model
step2 = Lasso(alpha=0.01, max_iter=10000)  # Increase max_iter to ensure convergence

# Full pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit model
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.7962211748387593
# MAE: 0.2175181759081616
# C:\Users\HP\CrossDevice\OPPO A17\anconda\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
from joblib import dump

df = dump(pipe, 'pipe.pkl')

# %%
df = dump('df' , 'df.pkl')

# %%
list(df['Company'].unique())
# Out:
# ['Apple',
#  'HP',
#  'Acer',
#  'Asus',
#  'Dell',
#  'Lenovo',
#  'Chuwi',
#  'MSI',
#  'Microsoft',
#  'Toshiba',
#  'Huawei',
#  'Xiaomi',
#  'Vero',
#  'Razer',
#  'Mediacom',
#  'Samsung',
#  'Google',
#  'Fujitsu',
#  'LG']
